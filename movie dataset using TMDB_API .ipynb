# %%
import pandas as pd
import requests

# %%
movies = pd.DataFrame()

# %%
for i in range(1,501):
    headers = {"accept": "application/json","Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNzJhZmMwNjQ2NzU5N2FkY2QwMTE0YjFkYWQwZDBiMCIsInN1YiI6IjYyZGQ0NmQxZWE4NGM3MDA2NzRhYTU1ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.10QUa8JMYbIZ1ljSPJF-sXfe389uc5Hpck-J8laFen4"}
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i), headers=headers)
    movies = movies.append(response.json()['results'], ignore_index=True)

# %%
movies_new = movies[['id','title','overview']]

# %%
movies_new
# Out:
#           id                            title  \
# 0        238                    The Godfather
# 1        278         The Shawshank Redemption
# 2        240            The Godfather Part II
# 3        424                 Schindler's List
# 4      19404      Dilwale Dulhania Le Jayenge
# ...      ...                              ...
# 9995  124459  The Incredible Burt Wonderstone
# 9996  523931                        Megalodon
# 9997  265208                        Wild Card
# 9998   51170                    Open Season 3
# 9999   39451                   Little Fockers
#
#                                                overview
# 0     Spanning the years 1945 to 1955, a chronicle o...
# 1     Framed in the 1940s for the double murder of h...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     Raj is a rich, carefree, happy-go-lucky second...
# ...                                                 ...
# ...

# %%
movies_id = movies_new['id'].values.tolist()
movies_id
# Out:
# [238,
#  278,
#  240,
#  424,
#  19404,
#  129,
#  389,
#  372058,
#  496243,
#  155,
#  497,
#  680,
#  13,
#  122,
#  429,
#  769,
#  11216,
#  346,
#  637,
#  12477,
#  696374,
#  772071,
#  569094,
#  539,
#  550,
#  620249,
#  372754,
#  311,
#  704264,
#  724089,
#  667257,
#  598,
#  14537,
#  510,
#  761053,
#  157336,
#  820067,
#  324857,
#  4935,
#  120,
#  378064,
#  40096,
#  1891,
#  255709,
#  568332,
#  121,
#  423,
#  244786,
#  92321,
#  995133,
#  807,
#  27205,
#  567,
#  599,
#  73,
#  18491,
#  12493,
#  652837,
#  3782,
#  274,
#  914,
#  128,
#  533514,
#  644479,
#  872585,
#  15804,
#  101,
#  207,
#  105,
#  851644,
#  901,
#  795607,
#  630566,
#  25237,
#  283566,
#  447362,
#  16672,
#  3082,
#  335,
#  20334,
#  527641,
#  29259,
#  10494,
#  28,
#  975,
#  637920,
#  77338,
#  315162,
#  897429,
#  361743,
#  10376,
#  670,
#  632632,
#  299534,
#  618344,
#  568300,
#  265177,
#  1585,
#  441130,
#  537061,
#  299536,
#  635302,
#  8587,
#  667276,
# ...

# %%
movies_cast = pd.DataFrame()

# %%
for i in movies_id:
    headers = {"accept": "application/json","Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNzJhZmMwNjQ2NzU5N2FkY2QwMTE0YjFkYWQwZDBiMCIsInN1YiI6IjYyZGQ0NmQxZWE4NGM3MDA2NzRhYTU1ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.10QUa8JMYbIZ1ljSPJF-sXfe389uc5Hpck-J8laFen4"}
    response = requests.get("https://api.themoviedb.org/3/movie/{}/credits?language=en-US".format(i) ,headers=headers)
    data = [[i,response.json().get('cast')]]
    temp = pd.DataFrame(data,columns=['id','Actors'])
    movies_cast = movies_cast.append(temp,ignore_index=True)

# %%
movies_cast
# Out:
#           id                                             Actors
# 0        238  [{'adult': False, 'gender': 2, 'id': 3084, 'kn...
# 1        278  [{'adult': False, 'gender': 2, 'id': 504, 'kno...
# 2        240  [{'adult': False, 'gender': 2, 'id': 1158, 'kn...
# 3        424  [{'adult': False, 'gender': 2, 'id': 3896, 'kn...
# 4      19404  [{'adult': False, 'gender': 2, 'id': 35742, 'k...
# ...      ...                                                ...
# 9995  124459  [{'adult': False, 'gender': 2, 'id': 4495, 'kn...
# 9996  523931  [{'adult': False, 'gender': 2, 'id': 147, 'kno...
# 9997  265208  [{'adult': False, 'gender': 2, 'id': 976, 'kno...
# 9998   51170  [{'adult': False, 'gender': 2, 'id': 1239270, ...
# 9999   39451  [{'adult': False, 'gender': 2, 'id': 380, 'kno...
#
# [10000 rows x 2 columns]

# %%
movies_cast['Actors'][2]
# Out:
# [{'adult': False,
#   'gender': 2,
#   'id': 1158,
#   'known_for_department': 'Acting',
#   'name': 'Al Pacino',
#   'original_name': 'Al Pacino',
#   'popularity': 34.104,
#   'profile_path': '/fMDFeVf0pjopTJbyRSLFwNDm8Wr.jpg',
#   'cast_id': 8,
#   'character': 'Don Michael Corleone',
#   'credit_id': '52fe422bc3a36847f8009505',
#   'order': 0},
#  {'adult': False,
#   'gender': 2,
#   'id': 3087,
#   'known_for_department': 'Acting',
#   'name': 'Robert Duvall',
#   'original_name': 'Robert Duvall',
#   'popularity': 19.95,
#   'profile_path': '/nLBIEvJDvSV0WhFv0bi7sU9tLyb.jpg',
#   'cast_id': 9,
#   'character': 'Tom Hagen',
#   'credit_id': '52fe422bc3a36847f8009509',
#   'order': 1},
#  {'adult': False,
#   'gender': 1,
#   'id': 3092,
#   'known_for_department': 'Acting',
#   'name': 'Diane Keaton',
#   'original_name': 'Diane Keaton',
#   'popularity': 18.888,
#   'profile_path': '/tnx7pJqisfAzvXOR5wHQsbnH9XH.jpg',
#   'cast_id': 10,
#   'character': 'Kay Corleone',
# ...

# %%
movies_crew=pd.DataFrame()

# %%
for i in movies_id:
    headers = {"accept": "application/json","Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNzJhZmMwNjQ2NzU5N2FkY2QwMTE0YjFkYWQwZDBiMCIsInN1YiI6IjYyZGQ0NmQxZWE4NGM3MDA2NzRhYTU1ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.10QUa8JMYbIZ1ljSPJF-sXfe389uc5Hpck-J8laFen4"}
    response = requests.get("https://api.themoviedb.org/3/movie/{}/credits?language=en-US".format(i) ,headers=headers)
    data = [[i,response.json().get('crew')]]
    temp = pd.DataFrame(data,columns=['id','crew'])
    movies_crew = movies_crew.append(temp,ignore_index=True)

# %%
movies_crew
# Out:
#           id                                               crew
# 0        238  [{'adult': False, 'gender': 2, 'id': 154, 'kno...
# 1        278  [{'adult': False, 'gender': 2, 'id': 153, 'kno...
# 2        240  [{'adult': False, 'gender': 2, 'id': 154, 'kno...
# 3        424  [{'adult': False, 'gender': 2, 'id': 491, 'kno...
# 4      19404  [{'adult': False, 'gender': 1, 'id': 8311, 'kn...
# ...      ...                                                ...
# 9995  124459  [{'adult': False, 'gender': 2, 'id': 298, 'kno...
# 9996  523931  [{'adult': False, 'gender': 2, 'id': 30053, 'k...
# 9997  265208  [{'adult': False, 'gender': 0, 'id': 297, 'kno...
# 9998   51170  [{'adult': False, 'gender': 2, 'id': 12095, 'k...
# 9999   39451  [{'adult': False, 'gender': 2, 'id': 380, 'kno...
#
# [10000 rows x 2 columns]

# %%
movies_crew['crew'][2]
# Out:
# [{'adult': False,
#   'gender': 2,
#   'id': 154,
#   'known_for_department': 'Editing',
#   'name': 'Walter Murch',
#   'original_name': 'Walter Murch',
#   'popularity': 2.679,
#   'profile_path': '/kQh7U7kRLF9NKEMpxiGjZEIu0o3.jpg',
#   'credit_id': '6489dd6be375c00139c283ed',
#   'department': 'Sound',
#   'job': 'Sound Editor'},
#  {'adult': False,
#   'gender': 2,
#   'id': 154,
#   'known_for_department': 'Editing',
#   'name': 'Walter Murch',
#   'original_name': 'Walter Murch',
#   'popularity': 2.679,
#   'profile_path': '/kQh7U7kRLF9NKEMpxiGjZEIu0o3.jpg',
#   'credit_id': '5a773d1f9251417763000e61',
#   'department': 'Sound',
#   'job': 'Sound Re-Recording Mixer'},
#  {'adult': False,
#   'gender': 2,
#   'id': 1776,
#   'known_for_department': 'Directing',
#   'name': 'Francis Ford Coppola',
#   'original_name': 'Francis Ford Coppola',
#   'popularity': 4.136,
#   'profile_path': '/3Pblihd6KjXliie9vj4iQJwbNPU.jpg',
#   'credit_id': '5e9251c384448e00128f09b1',
# ...

# %%
movies_genres = pd.DataFrame()

# %%
for i in movies_id:
    headers = {"accept": "application/json","Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNzJhZmMwNjQ2NzU5N2FkY2QwMTE0YjFkYWQwZDBiMCIsInN1YiI6IjYyZGQ0NmQxZWE4NGM3MDA2NzRhYTU1ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.10QUa8JMYbIZ1ljSPJF-sXfe389uc5Hpck-J8laFen4"}
    response = requests.get("https://api.themoviedb.org/3/movie/{}?language=en-US".format(i) ,headers=headers)
    data = [[i,response.json().get('genres')]]
    temp = pd.DataFrame(data,columns=['id','genres'])
    movies_genres = movies_genres.append(temp,ignore_index=True)

# %%
movies_genres
# Out:
#           id                                             genres
# 0        238  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 1        278  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2        240  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 3        424  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 4      19404  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...      ...                                                ...
# 9995  124459                     [{'id': 35, 'name': 'Comedy'}]
# 9996  523931  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 9997  265208  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 9998   51170  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 9999   39451  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
#
# [10000 rows x 2 columns]

# %%
movies_genres['genres'][0]
# Out:
# [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name': 'Crime'}]

# %%
movies_keywords = pd.DataFrame()

# %%
for i in movies_id:
    headers = {"accept": "application/json","Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJiNzJhZmMwNjQ2NzU5N2FkY2QwMTE0YjFkYWQwZDBiMCIsInN1YiI6IjYyZGQ0NmQxZWE4NGM3MDA2NzRhYTU1ZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.10QUa8JMYbIZ1ljSPJF-sXfe389uc5Hpck-J8laFen4"} 
    response = requests.get("https://api.themoviedb.org/3/movie/{}/keywords".format(i) ,headers=headers)
    data = [[i,response.json().get('keywords')]]
    temp = pd.DataFrame(data,columns=['id','keywords'])
    movies_keywords = movies_keywords.append(temp,ignore_index=True)

# %%
movies_keywords
# Out:
#           id                                           keywords
# 0        238  [{'id': 131, 'name': 'italy'}, {'id': 697, 'na...
# 1        278  [{'id': 378, 'name': 'prison'}, {'id': 417, 'n...
# 2        240  [{'id': 131, 'name': 'italy'}, {'id': 700, 'na...
# 3        424  [{'id': 818, 'name': 'based on novel or book'}...
# 4      19404  [{'id': 2783, 'name': 'family's daily life'}, ...
# ...      ...                                                ...
# 9995  124459  [{'id': 2343, 'name': 'magic'}, {'id': 14570, ...
# 9996  523931  [{'id': 339, 'name': 'submarine'}, {'id': 1299...
# 9997  265208  [{'id': 395, 'name': 'gambling'}, {'id': 3088,...
# 9998   51170  [{'id': 291, 'name': 'circus'}, {'id': 6054, '...
# 9999   39451  [{'id': 428, 'name': 'nurse'}, {'id': 977, 'na...
#
# [10000 rows x 2 columns]

# %%
movies_keywords['keywords'][2]
# Out:
# [{'id': 131, 'name': 'italy'},
#  {'id': 700, 'name': 'italian american'},
#  {'id': 701, 'name': 'cuba'},
#  {'id': 1715, 'name': 'symbolism'},
#  {'id': 3149, 'name': 'gangster'},
#  {'id': 4232, 'name': 'melancholy'},
#  {'id': 6049, 'name': 'praise'},
#  {'id': 9748, 'name': 'revenge'},
#  {'id': 10291, 'name': 'organized crime'},
#  {'id': 10391, 'name': 'mafia'},
#  {'id': 10909, 'name': 'lawyer'},
#  {'id': 14632, 'name': 'suburb'},
#  {'id': 156024, 'name': 'corrupt politician'}]

# %%
movies_new = movies_new.merge(movies_cast, on=['id'])
movies_new = movies_new.merge(movies_crew, on=['id'])
movies_new = movies_new.merge(movies_keywords, on=['id'])
movies_new = movies_new.merge(movies_genres,on=['id'])

movies_new
# Out:
#           id                            title  \
# 0        238                    The Godfather
# 1        278         The Shawshank Redemption
# 2        240            The Godfather Part II
# 3        424                 Schindler's List
# 4      19404      Dilwale Dulhania Le Jayenge
# ...      ...                              ...
# 9995  124459  The Incredible Burt Wonderstone
# 9996  523931                        Megalodon
# 9997  265208                        Wild Card
# 9998   51170                    Open Season 3
# 9999   39451                   Little Fockers
#
#                                                overview  \
# 0     Spanning the years 1945 to 1955, a chronicle o...
# 1     Framed in the 1940s for the double murder of h...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     Raj is a rich, carefree, happy-go-lucky second...
# ...                                                 ...
# ...

# %%
movies_new.to_csv('Final_Dataset.csv', index=False, mode='a')

# %%
movies_new
# Out:
#           id                            title  \
# 0        238                    The Godfather
# 1        278         The Shawshank Redemption
# 2        240            The Godfather Part II
# 3        424                 Schindler's List
# 4      19404      Dilwale Dulhania Le Jayenge
# ...      ...                              ...
# 9995  124459  The Incredible Burt Wonderstone
# 9996  523931                        Megalodon
# 9997  265208                        Wild Card
# 9998   51170                    Open Season 3
# 9999   39451                   Little Fockers
#
#                                                overview  \
# 0     Spanning the years 1945 to 1955, a chronicle o...
# 1     Framed in the 1940s for the double murder of h...
# 2     In the continuing saga of the Corleone crime f...
# 3     The true story of how businessman Oskar Schind...
# 4     Raj is a rich, carefree, happy-go-lucky second...
# ...                                                 ...
# ...
